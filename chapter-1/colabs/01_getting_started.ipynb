# %% [markdown]
# # Chapter 1: Getting Started with LLM Development
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/yourusername/genai-on-google-cloud/blob/main/chapter-1/colabs/01_getting_started.ipynb)
#
# ## Setup

# %%
# Install required packages
# !pip install google-cloud-aiplatform -q

# Import libraries
import vertexai
from vertexai.generative_models import GenerativeModel
